# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('t20_df_2.pkl', 'rb'))

# %%
df

# batting_team
# bowling_team
# city
# current score
# balls left
# wickets left
# crr
# last five overs run
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0               NA      NaN
# 1           2    Australia    Sri Lanka   0.2     0               NA      NaN
# 2           2    Australia    Sri Lanka   0.3     1               NA      NaN
# 3           2    Australia    Sri Lanka   0.4     2               NA      NaN
# 4           2    Australia    Sri Lanka   0.5     0               NA      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1               NA  Colombo
# 122       964    Sri Lanka    Australia  19.4     0               NA  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2               NA  Colombo
# 125       964    Sri Lanka    Australia  19.7     1               NA  Colombo
#
#                         venue
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
df['venue'].str.split().apply(lambda x:x[0]).unique()
# Out:
# array(['Melbourne', 'Simonds', 'Adelaide', 'McLean', 'Bay', 'Eden', 'The',
#        'County', 'Sophia', 'Riverside', 'Green', 'Vidarbha', 'M',
#        'Central', 'Dubai', 'Sheikh', 'Sydney', 'Bellerive', 'Westpac',
#        'Seddon', 'Mangaung', 'Senwes', 'Kensington', "Queen's", 'R',
#        'Warner', 'Sabina', 'R.Premadasa', 'Saxton', 'JSCA', 'Edgbaston',
#        'Old', 'Arun', 'Saurashtra', 'Greenfield', 'Gaddafi', 'SuperSport',
#        'Newlands', 'Barabati', 'Holkar', 'Wankhede', 'Shere', 'Sylhet',
#        'National', 'Harare', 'Carrara', 'Brisbane', 'Rajiv', 'Bharat',
#        'MA', 'Darren', 'Dr.', 'M.Chinnaswamy', 'Manuka', 'Perth',
#        'Buffalo', 'Kingsmead', 'St', 'Punjab', 'Hagley', 'Providence',
#        'Pallekele', 'Zahur', 'Maharashtra', 'Boland', 'New', 'Kennington',
#        'Western', 'Brabourne', 'Jade', 'Gymkhana', 'Trent', "Lord's",
#        'Maple', 'AMI', 'Beausejour', 'Sir', 'Moses', 'Stadium', 'Mahinda',
# ...

# %%
cities = np.where(df['city'].isnull(), df['venue'].str.split().apply(lambda x:x[0]), df['city'])

## like ternary operator -> if city null, fill first value, else fill city value

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'], inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0               NA
# 1           2    Australia    Sri Lanka   0.2     0               NA
# 2           2    Australia    Sri Lanka   0.3     1               NA
# 3           2    Australia    Sri Lanka   0.4     2               NA
# 4           2    Australia    Sri Lanka   0.5     0               NA
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1               NA
# 122       964    Sri Lanka    Australia  19.4     0               NA
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2               NA
# 125       964    Sri Lanka    Australia  19.7     1               NA
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
eligible_cities=df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0               NA
# 1           2    Australia    Sri Lanka   0.2     0               NA
# 2           2    Australia    Sri Lanka   0.3     1               NA
# 3           2    Australia    Sri Lanka   0.4     2               NA
# 4           2    Australia    Sri Lanka   0.5     0               NA
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1               NA
# 122       964    Sri Lanka    Australia  19.4     0               NA
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2               NA
# 125       964    Sri Lanka    Australia  19.7     1               NA
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
df['current_score']=df.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\2789925231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score']=df.groupby('match_id')['runs'].cumsum()

# %%
print(df.columns)
print(df.dtypes)
# Out:
# Index(['match_id', 'batting_team', 'bowling_team', 'ball', 'runs',
#        'player_dismissed', 'city', 'current_score'],
#       dtype='object')
# match_id              int64
# batting_team         object
# bowling_team         object
# ball                float64
# runs                  int64
# player_dismissed     object
# city                 object
# current_score         int64
# dtype: object

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0               NA
# 1           2    Australia    Sri Lanka   0.2     0               NA
# 2           2    Australia    Sri Lanka   0.3     1               NA
# 3           2    Australia    Sri Lanka   0.4     2               NA
# 4           2    Australia    Sri Lanka   0.5     0               NA
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1               NA
# 122       964    Sri Lanka    Australia  19.4     0               NA
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2               NA
# 125       964    Sri Lanka    Australia  19.7     1               NA
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\1757844946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\1757844946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\572800509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x < 0 else x)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\1028181820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\1028181820.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x < 0 else x)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0               NA
# 1           2    Australia    Sri Lanka   0.2     0               NA
# 2           2    Australia    Sri Lanka   0.3     1               NA
# 3           2    Australia    Sri Lanka   0.4     2               NA
# 4           2    Australia    Sri Lanka   0.5     0               NA
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1               NA
# 122       964    Sri Lanka    Australia  19.4     0               NA
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2               NA
# 125       964    Sri Lanka    Australia  19.7     1               NA
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x == 'NA' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\2324103836.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x == 'NA' else 1)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\2324103836.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\2324103836.py:3: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30)['runs'].sum().values.tolist())

# %%
df['last_five']=last_five
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4164\2265987530.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five']=last_five

# %%
final_df=df.groupby('match_id')['runs'].sum().reset_index().merge(df, on='match_id')

# %%
final_df = final_df[['batting_team', 'bowling_team', 'city', 'current_score', 'balls_left', 'wickets_left', 'crr', 'last_five', 'runs_x']]

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team bowling_team             city  current_score  balls_left  \
# 6571   South Africa     Pakistan        Cape Town            183           7
# 25675   New Zealand      England         St Lucia            124          21
# 34800   West Indies  New Zealand       Lauderhill             43          84
# 28707         India      England       Manchester            104          50
# 3810    New Zealand  West Indies  Mount Maunganui            110          60
# ...             ...          ...              ...            ...         ...
# 12602     Sri Lanka     Pakistan           Lahore             69          69
# 26022     Sri Lanka      England         St Lucia             75          42
# 2853     Bangladesh    Sri Lanka          Colombo            142           9
# 35828   New Zealand      England         Hamilton            112          40
# 4173       Pakistan  New Zealand  Mount Maunganui             58          71
#
# ...

# %%
pickle.dump(final_df, open('t20_df_3.pkl', 'wb'))
